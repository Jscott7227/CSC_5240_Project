# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("train_u6lujuX_CVtuZ9i.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sex = pd.get_dummies(df['Gender'],drop_first=True)

# %%
df.drop(['Gender','Loan_ID'],axis=1,inplace=True)
df = pd.concat([df,sex],axis=1)
df.head()
# Out:
#   Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      No          0      Graduate            No             5849
# 1     Yes          1      Graduate            No             4583
# 2     Yes          0      Graduate           Yes             3000
# 3     Yes          0  Not Graduate            No             2583
# 4      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Male
# 0         Urban           Y  True
# 1         Rural           N  True
# 2         Urban           Y  True
# 3         Urban           Y  True
# 4         Urban           Y  True

# %%
married = pd.get_dummies(df['Married'],drop_first=True)
education = pd.get_dummies(df['Education'],drop_first=True)
df.drop(['Married','Education'],axis=1,inplace=True)
df = pd.concat([df,married,education],axis=1)
df.head()
# Out:
#   Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0            No             5849                0.0         NaN
# 1          1            No             4583             1508.0       128.0
# 2          0           Yes             3000                0.0        66.0
# 3          0            No             2583             2358.0       120.0
# 4          0            No             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History Property_Area Loan_Status  Male    Yes  \
# 0             360.0             1.0         Urban           Y  True  False
# 1             360.0             1.0         Rural           N  True   True
# 2             360.0             1.0         Urban           Y  True   True
# 3             360.0             1.0         Urban           Y  True   True
# 4             360.0             1.0         Urban           Y  True  False
#
#    Not Graduate
# 0         False
# 1         False
# 2         False
# 3          True
# 4         False

# %%
df=df.rename(columns={'Yes':'Married','Male':'Gender'})
df.head()
# Out:
#   Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0            No             5849                0.0         NaN
# 1          1            No             4583             1508.0       128.0
# 2          0           Yes             3000                0.0        66.0
# 3          0            No             2583             2358.0       120.0
# 4          0            No             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History Property_Area Loan_Status  Gender  \
# 0             360.0             1.0         Urban           Y    True
# 1             360.0             1.0         Rural           N    True
# 2             360.0             1.0         Urban           Y    True
# 3             360.0             1.0         Urban           Y    True
# 4             360.0             1.0         Urban           Y    True
#
#    Married  Not Graduate
# 0    False         False
# 1     True         False
# 2     True         False
# 3     True          True
# 4    False         False

# %%
df=df.rename(columns={'Sf':'Self_Employed'})
df.head()
# Out:
#   Dependents Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0            No             5849                0.0         NaN
# 1          1            No             4583             1508.0       128.0
# 2          0           Yes             3000                0.0        66.0
# 3          0            No             2583             2358.0       120.0
# 4          0            No             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History Property_Area Loan_Status  Gender  \
# 0             360.0             1.0         Urban           Y    True
# 1             360.0             1.0         Rural           N    True
# 2             360.0             1.0         Urban           Y    True
# 3             360.0             1.0         Urban           Y    True
# 4             360.0             1.0         Urban           Y    True
#
#    Married  Not Graduate
# 0    False         False
# 1     True         False
# 2     True         False
# 3     True          True
# 4    False         False

# %%
self_emp = pd.get_dummies(df['Self_Employed'],drop_first=True)
df.drop(['Self_Employed'],axis=1,inplace=True)
df = pd.concat([df,self_emp],axis=1)
df.head()
# Out:
#   Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0             5849                0.0         NaN
# 1          1             4583             1508.0       128.0
# 2          0             3000                0.0        66.0
# 3          0             2583             2358.0       120.0
# 4          0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History Property_Area Loan_Status  Gender  \
# 0             360.0             1.0         Urban           Y    True
# 1             360.0             1.0         Rural           N    True
# 2             360.0             1.0         Urban           Y    True
# 3             360.0             1.0         Urban           Y    True
# 4             360.0             1.0         Urban           Y    True
#
#    Married  Not Graduate    Yes
# 0    False         False  False
# 1     True         False  False
# 2     True         False   True
# 3     True          True  False
# 4    False         False  False

# %%
df=df.rename(columns={'Yes':'Self_Employed'})
df.head(50)
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0           0             5849                0.0         NaN
# 1           1             4583             1508.0       128.0
# 2           0             3000                0.0        66.0
# 3           0             2583             2358.0       120.0
# 4           0             6000                0.0       141.0
# 5           2             5417             4196.0       267.0
# 6           0             2333             1516.0        95.0
# 7          3+             3036             2504.0       158.0
# 8           2             4006             1526.0       168.0
# 9           1            12841            10968.0       349.0
# 10          2             3200              700.0        70.0
# 11          2             2500             1840.0       109.0
# 12          2             3073             8106.0       200.0
# 13          0             1853             2840.0       114.0
# 14          2             1299             1086.0        17.0
# 15          0             4950                0.0       125.0
# 16          1             3596                0.0       100.0
# 17          0             3510                0.0        76.0
# 18          0             4887                0.0       133.0
# 19          0             2600             3500.0       115.0
# 20          0             7660                0.0       104.0
# 21          1             5955             5625.0       315.0
# 22          0             2600             1911.0       116.0
# 23          2             3365             1917.0       112.0
# 24          1             3717             2925.0       151.0
# 25          0             9560                0.0       191.0
# 26          0             2799             2253.0       122.0
# 27          2             4226             1040.0       110.0
# 28          0             1442                0.0        35.0
# 29          2             3750             2083.0       120.0
# 30          1             4166             3369.0       201.0
# 31          0             3167                0.0        74.0
# 32          1             4692                0.0       106.0
# 33          0             3500             1667.0       114.0
# 34         3+            12500             3000.0       320.0
# 35          0             2275             2067.0         NaN
# 36          0             1828             1330.0       100.0
# 37          0             3667             1459.0       144.0
# 38          0             4166             7210.0       184.0
# 39          0             3748             1668.0       110.0
# 40          0             3600                0.0        80.0
# 41          0             1800             1213.0        47.0
# 42          0             2400                0.0        75.0
# 43          0             3941             2336.0       134.0
# 44          0             4695                0.0        96.0
# 45          0             3410                0.0        88.0
# 46          1             5649                0.0        44.0
# 47          0             5821                0.0       144.0
# 48          0             2645             3440.0       120.0
# 49          0             4000             2275.0       144.0
#
#     Loan_Amount_Term  Credit_History Property_Area Loan_Status  Gender  \
# 0              360.0             1.0         Urban           Y    True
# 1              360.0             1.0         Rural           N    True
# 2              360.0             1.0         Urban           Y    True
# 3              360.0             1.0         Urban           Y    True
# 4              360.0             1.0         Urban           Y    True
# 5              360.0             1.0         Urban           Y    True
# 6              360.0             1.0         Urban           Y    True
# 7              360.0             0.0     Semiurban           N    True
# 8              360.0             1.0         Urban           Y    True
# 9              360.0             1.0     Semiurban           N    True
# 10             360.0             1.0         Urban           Y    True
# 11             360.0             1.0         Urban           Y    True
# 12             360.0             1.0         Urban           Y    True
# 13             360.0             1.0         Rural           N    True
# 14             120.0             1.0         Urban           Y    True
# 15             360.0             1.0         Urban           Y    True
# 16             240.0             NaN         Urban           Y    True
# 17             360.0             0.0         Urban           N   False
# 18             360.0             1.0         Rural           N    True
# 19               NaN             1.0         Urban           Y    True
# 20             360.0             0.0         Urban           N    True
# 21             360.0             1.0         Urban           Y    True
# 22             360.0             0.0     Semiurban           N    True
# 23             360.0             0.0         Rural           N   False
# 24             360.0             NaN     Semiurban           N    True
# 25             360.0             1.0     Semiurban           Y    True
# 26             360.0             1.0     Semiurban           Y    True
# 27             360.0             1.0         Urban           Y    True
# 28             360.0             1.0         Urban           N    True
# 29             360.0             1.0     Semiurban           Y   False
# 30             360.0             NaN         Urban           N    True
# 31             360.0             1.0         Urban           N    True
# 32             360.0             1.0         Rural           N    True
# 33             360.0             1.0     Semiurban           Y    True
# 34             360.0             1.0         Rural           N    True
# 35             360.0             1.0         Urban           Y    True
# 36               NaN             0.0         Urban           N    True
# 37             360.0             1.0     Semiurban           Y   False
# 38             360.0             1.0         Urban           Y    True
# 39             360.0             1.0     Semiurban           Y    True
# 40             360.0             1.0         Urban           N    True
# 41             360.0             1.0         Urban           Y    True
# 42             360.0             NaN         Urban           Y    True
# 43             360.0             1.0     Semiurban           Y    True
# 44               NaN             1.0         Urban           Y    True
# 45               NaN             1.0         Urban           Y   False
# 46             360.0             1.0         Urban           Y    True
# 47             360.0             1.0         Urban           Y    True
# 48             360.0             0.0         Urban           N   False
# 49             360.0             1.0     Semiurban           Y   False
#
#     Married  Not Graduate  Self_Employed
# 0     False         False          False
# 1      True         False          False
# 2      True         False           True
# 3      True          True          False
# 4     False         False          False
# 5      True         False           True
# 6      True          True          False
# 7      True         False          False
# 8      True         False          False
# 9      True         False          False
# 10     True         False          False
# 11     True         False          False
# 12     True         False          False
# 13    False         False          False
# 14     True         False          False
# 15    False         False          False
# 16    False          True          False
# 17    False         False          False
# 18     True          True          False
# 19     True         False          False
# 20     True          True          False
# 21     True         False          False
# 22     True          True          False
# 23     True          True          False
# 24     True         False          False
# 25     True         False           True
# 26     True         False          False
# 27     True          True          False
# 28    False          True          False
# 29    False         False          False
# 30     True         False          False
# 31    False         False          False
# 32    False         False           True
# 33     True         False          False
# 34    False         False          False
# 35     True         False          False
# 36     True         False          False
# 37     True         False          False
# 38    False         False          False
# 39    False          True          False
# 40    False         False          False
# 41    False         False          False
# 42     True         False          False
# 43     True         False          False
# 44     True          True           True
# 45    False         False          False
# 46     True         False          False
# 47     True         False          False
# 48     True         False          False
# 49    False         False          False

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 7))
bx=sns.boxplot(x='Self_Employed',y='LoanAmount',data=df,palette='winter')
medians=df.groupby(['Self_Employed'])['LoanAmount'].median()
vertical_offset=df['LoanAmount'].median() * 0.05
for xtick in bx.get_xticks():
    bx.text(xtick,medians[xtick]+vertical_offset,medians[xtick],horizontalalignment='center',size='x-small',color='w',weight='semibold')
# Out:
# C:\Users\jwhoo\AppData\Local\Temp\ipykernel_8232\1984027794.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bx=sns.boxplot(x='Self_Employed',y='LoanAmount',data=df,palette='winter', legend=False)
# C:\Users\jwhoo\AppData\Local\Temp\ipykernel_8232\1984027794.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bx.text(xtick,medians[xtick]+vertical_offset,medians.iloc[xtick],horizontalalignment='center',size='x-small',color='w',weight='semibold')

# %%
def impute_LoanAmt(cols):
    Loan = cols.iloc[0]
    selfemp = cols.iloc[1]
    
    if pd.isnull(Loan):

        if selfemp == 1:
            return 150
        else:
            return 125

    else:
        return Loan

# %%
df['LoanAmount'] = df[['LoanAmount','Self_Employed']].apply(impute_LoanAmt,axis=1)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='Credit_History',data=df,hue='Credit_History',palette='RdBu_r')
# Out:
# <Axes: xlabel='Credit_History', ylabel='count'>

# %%
df['Credit_History'].fillna(1.0,inplace=True)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='Loan_Amount_Term',data=df,hue='Loan_Amount_Term',palette='RdBu_r')
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='count'>

# %%
df['Loan_Amount_Term'].fillna(360.0,inplace=True)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='Dependents',data=df,hue='Dependents',palette='RdBu_r')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
df['Dependents'].fillna(0,inplace=True)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
loanStatus = pd.get_dummies(df['Loan_Status'],drop_first=True)
df.drop(['Loan_Status'],axis=1,inplace=True)
df = pd.concat([df,loanStatus],axis=1)
df.head()
# Out:
#   Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0             5849                0.0       125.0
# 1          1             4583             1508.0       128.0
# 2          0             3000                0.0        66.0
# 3          0             2583             2358.0       120.0
# 4          0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History Property_Area  Gender  Married  \
# 0             360.0             1.0         Urban    True    False
# 1             360.0             1.0         Rural    True     True
# 2             360.0             1.0         Urban    True     True
# 3             360.0             1.0         Urban    True     True
# 4             360.0             1.0         Urban    True    False
#
#    Not Graduate  Self_Employed      Y
# 0         False          False   True
# 1         False          False  False
# 2         False           True   True
# 3          True          False   True
# 4         False          False   True

# %%
PropArea = pd.get_dummies(df['Property_Area'],drop_first=True)
df.drop(['Property_Area'],axis=1,inplace=True)
df = pd.concat([df,PropArea],axis=1)
df.head()
# Out:
#   Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0          0             5849                0.0       125.0
# 1          1             4583             1508.0       128.0
# 2          0             3000                0.0        66.0
# 3          0             2583             2358.0       120.0
# 4          0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Gender  Married  Not Graduate  \
# 0             360.0             1.0    True    False         False
# 1             360.0             1.0    True     True         False
# 2             360.0             1.0    True     True         False
# 3             360.0             1.0    True     True          True
# 4             360.0             1.0    True    False         False
#
#    Self_Employed      Y  Semiurban  Urban
# 0          False   True      False   True
# 1          False  False      False  False
# 2           True   True      False   True
# 3          False   True      False   True
# 4          False   True      False   True

# %%
df=df.rename(columns={'Y':'Loan_Status'})

# %%
df=df.replace(to_replace='3+',value=3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train=pd.DataFrame(df.drop('Loan_Status',axis=1))
scaler.fit(train)
scaled_features = scaler.transform(train)
df_feat = pd.DataFrame(scaled_features,columns=train.columns)
df_feat.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0   -0.737806         0.072991          -0.554487   -0.247076
# 1    0.253470        -0.134412          -0.038732   -0.211384
# 2   -0.737806        -0.393747          -0.554487   -0.949028
# 3   -0.737806        -0.462062           0.251980   -0.306564
# 4   -0.737806         0.097728          -0.554487   -0.056717
#
#    Loan_Amount_Term  Credit_History    Gender   Married  Not Graduate  \
# 0          0.273231        0.411733  0.505592 -1.357421     -0.528362
# 1          0.273231        0.411733  0.505592  0.736691     -0.528362
# 2          0.273231        0.411733  0.505592  0.736691     -0.528362
# 3          0.273231        0.411733  0.505592  0.736691      1.892641
# 4          0.273231        0.411733  0.505592 -1.357421     -0.528362
#
#    Self_Employed  Semiurban     Urban
# 0      -0.392601  -0.782016  1.428147
# 1      -0.392601  -0.782016 -0.700208
# 2       2.547117  -0.782016  1.428147
# 3      -0.392601  -0.782016  1.428147
# 4      -0.392601  -0.782016  1.428147

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_features,df['Loan_Status'],
                                                    test_size=0.30)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import classification_report,confusion_matrix
pred = knn.predict(X_test)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[ 27  24]
#  [ 18 116]]
#               precision    recall  f1-score   support
#
#        False       0.60      0.53      0.56        51
#         True       0.83      0.87      0.85       134
#
#     accuracy                           0.77       185
#    macro avg       0.71      0.70      0.70       185
# weighted avg       0.77      0.77      0.77       185

# %%
knn.predict([X_test[0]])
X_test[0]
# Out:
# array([-0.73780632, -0.06609682, -0.55448733, -0.50882115,  0.2732313 ,
#        -2.42876026, -1.97787765, -1.3574213 , -0.52836225, -0.39260074,
#         1.2787467 , -0.70020801])

# %%
features=np.array([1,0,3,1,4000,3000,0,1,360,1.0])
features = scaler.fit_transform(features.reshape(-1, 1))
features=features.flatten()
features
# Out:
# array([-0.52413336, -0.52484579, -0.52270851, -0.52413336,  2.32486667,
#         1.61243855, -0.52484579, -0.52413336, -0.26837167, -0.52413336])

# %%
error_rate = []

for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
pred = knn.predict(X_test)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[ 24  27]
#  [  9 125]]
#               precision    recall  f1-score   support
#
#        False       0.73      0.47      0.57        51
#         True       0.82      0.93      0.87       134
#
#     accuracy                           0.81       185
#    macro avg       0.77      0.70      0.72       185
# weighted avg       0.80      0.81      0.79       185

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pred))
# Out:
# 0.8054054054054054

# %%
df['Dependents'] = pd.to_numeric(df['Dependents'])

# %%
df.columns
# Out:
# Index(['Dependents', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Gender', 'Married',
#        'Not Graduate', 'Self_Employed', 'Loan_Status', 'Semiurban', 'Urban'],
#       dtype='object')

# %%
x=df[['Married', 'Not Graduate', 'Dependents',
       'Self_Employed','ApplicantIncome','CoapplicantIncome','Semiurban','Urban','Loan_Amount_Term','Credit_History']]
y=df['LoanAmount']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x.values,y.values,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 55.50899686609256

# %%
coeff=pd.DataFrame(lm.coef_,x.columns,columns=['Coefficient'])
coeff
# Out:
#                    Coefficient
# Married              20.641931
# Not Graduate        -17.026395
# Dependents           10.201953
# Self_Employed        14.170060
# ApplicantIncome       0.006799
# CoapplicantIncome     0.006619
# Semiurban            -7.765598
# Urban               -11.591580
# Loan_Amount_Term      0.089799
# Credit_History       -1.739083

# %%
pred1=lm.predict(X_test)

# %%
from sklearn.metrics import max_error,explained_variance_score,mean_absolute_error
print(max_error(Y_test,pred1))
print(explained_variance_score(Y_test,pred1))
print(mean_absolute_error(Y_test,pred1))
# Out:
# 413.43499346247575
# 0.3214675018094072
# 41.801807761226094

# %%
dfx = pd.DataFrame({

   'Original': Y_test,

   'Predicted': pred1

   })

# %%
lm.predict([[1,0,3,1,4000,3000,0,1,360,1.0]])
# Out:
# array([186.97891948])

# %%
from sklearn import linear_model

# %%
bm=linear_model.BayesianRidge()
bm.fit(X_train,Y_train)
# Out:
# BayesianRidge()

# %%
pred2=bm.predict(X_test)

# %%
bm.predict([[1,0,3,1,4000,3000,0,1,360,1.0]])
# Out:
# array([143.98938586])

# %%
print(max_error(Y_test,pred2))
print(explained_variance_score(Y_test,pred2))
print(mean_absolute_error(Y_test,pred2))
# Out:
# 408.17309929462266
# 0.360837698616553
# 40.4067450010123

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\jwhoo\pycharmprojects\ai5240\venv\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy in c:\users\jwhoo\pycharmprojects\ai5240\venv\lib\site-packages (from xgboost) (1.26.2)
# Requirement already satisfied: scipy in c:\users\jwhoo\pycharmprojects\ai5240\venv\lib\site-packages (from xgboost) (1.11.4)
# WARNING: You are using pip version 21.3.1; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\jwhoo\PycharmProjects\AI5240\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from xgboost import XGBRegressor
model=XGBRegressor()
model.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
yhat = model.predict([[1,0,3,1,4000,3000,0,1,360,1.0]])
print('Predicted: %.3f' % yhat)
# Out:
# Predicted: 154.216
# C:\Users\jwhoo\AppData\Local\Temp\ipykernel_8232\3759751574.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('Predicted: %.3f' % yhat)

# %%
pred3=model.predict(X_test)

# %%
print(explained_variance_score(Y_test,pred3))
print(max_error(Y_test,pred3))
# Out:
# 0.38255517556988683
# 274.5325469970703

# %%
 from sklearn.ensemble import RandomForestRegressor
 regr = RandomForestRegressor(max_depth=2, random_state=0)
 regr.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(max_depth=2, random_state=0)

# %%
regr.predict([[1,0,3,1,4000,3000,0,1,360,1.0]])
# Out:
# array([123.46250175])

# %%
pred4=regr.predict(X_test)

# %%
print(explained_variance_score(Y_test,pred4))
print(max_error(Y_test,pred4))
# Out:
# 0.41044459436904535
# 295.2034414641407
